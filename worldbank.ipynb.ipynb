# %%
import requests

# %%
endpoint = "https://api.worldbank.org/v2/country/US/indicator/NY.GDP.MKTP.KD.ZG?format=json&date=2000:2023"

# %%
data = requests.get(endpoint)
worlddata = data.json()

# %%
data_list = worlddata[1]  
data_list
# Out:
# [{'indicator': {'id': 'NY.GDP.MKTP.KD.ZG', 'value': 'GDP growth (annual %)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2023',
#   'value': 2.88755600749487,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'NY.GDP.MKTP.KD.ZG', 'value': 'GDP growth (annual %)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2022',
#   'value': 2.51237531986017,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'NY.GDP.MKTP.KD.ZG', 'value': 'GDP growth (annual %)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2021',
#   'value': 6.05505293244555,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'NY.GDP.MKTP.KD.ZG', 'value': 'GDP growth (annual %)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
# ...

# %%
import pandas as pd
pip install reportlab

clean_data = []

for entry in data_list:
    clean_data.append({
        "Country": entry["country"]["value"],
        "Year": entry["date"],
        "Indicator": entry["indicator"]["value"],
        "Value": entry["value"],
        "Unit": entry["unit"]
    })

df = pd.DataFrame(clean_data)
country = df
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 1.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 0.8/2.0 MB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 1.5 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/2.0 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.4 MB/s  0:00:01
# ...

# %%
pip install reportlab

# %%
import pandas as pd

clean_data = []

for entry in data_list:
    clean_data.append({
        "Country": entry["country"]["value"],
        "Year": entry["date"],
        "Indicator": entry["indicator"]["value"],
        "Value": entry["value"],
        "Unit": entry["unit"]
    })

df = pd.DataFrame(clean_data)
df
# Out:
#    Country  Year              Indicator     Value Unit
# 0    Kenya  2023  GDP growth (annual %)  5.719992
# 1    Kenya  2022  GDP growth (annual %)  4.859981
# 2    Kenya  2021  GDP growth (annual %)  7.590489
# 3    Kenya  2020  GDP growth (annual %) -0.272766
# 4    Kenya  2019  GDP growth (annual %)  5.114159
# 5    Kenya  2018  GDP growth (annual %)  5.647946
# 6    Kenya  2017  GDP growth (annual %)  3.837958
# 7    Kenya  2016  GDP growth (annual %)  4.213517
# 8    Kenya  2015  GDP growth (annual %)  4.967721
# 9    Kenya  2014  GDP growth (annual %)  5.020111
# 10   Kenya  2013  GDP growth (annual %)  3.797848
# 11   Kenya  2012  GDP growth (annual %)  4.568680
# 12   Kenya  2011  GDP growth (annual %)  5.121106
# 13   Kenya  2010  GDP growth (annual %)  8.058474
# 14   Kenya  2009  GDP growth (annual %)  3.306940
# 15   Kenya  2008  GDP growth (annual %)  0.232283
# 16   Kenya  2007  GDP growth (annual %)  6.850730
# 17   Kenya  2006  GDP growth (annual %)  6.472494
# ...

# %%
from reportlab.platypus import SimpleDocTemplate, Table, TableStyle
from reportlab.lib import colors

doc = SimpleDocTemplate("GDP_Report.pdf")


table_data = [df.columns.tolist()] + df.values.tolist()

table = Table(table_data)


style = TableStyle([
    ('BACKGROUND', (0,0), (-1,0), colors.grey),
    ('TEXTCOLOR', (0,0), (-1,0), colors.white),
    ('GRID', (0,0), (-1,-1), 1, colors.black)
])
table.setStyle(style)

doc.build([table])
